# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 3</h2>
#
# Привет. Оформление комментариев по работе сохраняется. Только обозначим, что это третья итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Привет еще раз. Спасибо, что доделал работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Привет, Артемий! Спасибо, что прислал задание:) Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделал большую работу над проектом, однако его еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> - всё сделано правильно. Рекомендации укажу таким же цветом; <font color=orange>оранжевый</font> - некритичные замечания. Если таких замечаний меньше трех - проект может быть принят без их отработки; <font color=red>красный</font> - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Стоит делать краткое вступление в работу, описание того, что надо делать. В работе необходимо приводить краткий план того, что надо сделать (если этот план имеется), а также информацию о входных данных: какие столбцы есть в таблице, их названия и какую информацию они несут. Также название работы лучше отображать в отдельной ячейке и делать крупный шрифт (заголовок). Так работа выглядит презентабельно.
#
# </div>

# %% [markdown]
# # Сборный проект. Анализ рынка компьютерных игр.

# %% [markdown]
# ## Задача
#
# Необходимо выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы до 2016 года. Мы планируем компанию на 2017 год.

# %% [markdown]
# ## Описание данных
#
# Name — название игры
#
# Platform — платформа
#
# Year_of_Release — год выпуска
#
# Genre — жанр игры
#
# NA_sales — продажи в Северной Америке (миллионы долларов)
#
# EU_sales — продажи в Европе (миллионы долларов)
#
# JP_sales — продажи в Японии (миллионы долларов)
#
# Other_sales — продажи в других странах (миллионы долларов)
#
# Critic_Score — оценка критиков (от 0 до 100)
#
# User_Score — оценка пользователей (от 0 до 10)
#
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ## План выполнения проекта
#
# 1) Изучение общей информации
#
# 2) Подготовка данных
#
#     2.1 Приведение названий столбцов к нижнему регистру.
#
#     2.2 Преобразование данных в нужные типы.
#
#     2.3 Обработка пропусков и описание их причин.
#
#     2.4 Подсчет суммарных продаж во всех регионах и запись их в отдельный столбец.
#
# 3) Исследовательский анализ данных
#
#     3.1 Определение количества выпущенных игр в разные годы. Определение актуального периода.
#
#     3.2 Фиксация изменений продаж по платформам. Выбор платформ с наибольшими суммарными продажами и построение распределения по годам. Поиск популярных в прошлом платформ, у которых сейчас продажи на нуле. Определение характерного периода появления новых и исчезновения старых платформ?
#
#     3.4 Определение данных за период, чтобы исключить значимое искажение распределения по платформам в 2016 году.
#
#     3.5 Опредление платформ лидирующих по продажам, растущих и падающих. Выбор несколько потенциально прибыльных платформ.
#
#     3.6 Построние графика «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Определение разницы в продажах.
#
#     3.7 Влияние отзывов пользователей и критиков на продажи внутри одной популярной платформы. Построение диаграммы рассеяния и расчет корреляции между отзывами и продажами.
#
#     3.8 Обзор общего распределения игр по жанрам.
#
# 4)  Портрет пользователя каждого региона
#
#     Определение для пользователя каждого региона (NA, EU, JP):
#
#         Самых популярных платформ (топ-5).
#
#         Самых популярных жанров (топ-5).
#
#         Влияние ли рейтинга ESRB на продажи в отдельном регионе.
#
# 5) Исследование статистических показателей
#
#     Вариативность пользовательского рейтинга и рейтинга критиков в различных жанрах. Расчет среднего количества, дисперсии и стандартного отклонения. Построение гистограмм. Описание распределений
#
# 6) Проверка гипотез:
#
#     а) Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
#     б) Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.
#
# 7) Общий вывод и рекомендации

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Цель работы также хорошо бы вынести в отдельный блок вступления. Еще лучше будет, если ты сделаешь план работы с гиперссылками. Как это реализовать - смотри по [ссылке](https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704).
#
# </div>

# %%
#импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import numpy as np

# %%
df = pd.read_csv('/datasets/games.csv')

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
df.shape
# Out:
# (16715, 11)

# %%
#общая информация о данных в таблице df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
#названия столбцов
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
#приведем названия столбцов к нижнему регистру

# исходный вариант: df.set_axis(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales', 'jp_sales','other_sales', 'critic_score','user_score','rating'], axis='columns', inplace=True)

# исправленный: 
df = df.rename(columns={"Name": "name", 'Platform': 'platform', 'Year_of_Release' : 'year_of_release', 'Genre': 'genre', 'NA_sales': 'na_sales', 'EU_sales': 'eu_sales',
       'JP_sales': 'jp_sales', 'Other_sales': 'other_sales', 'Critic_Score': 'critic_score', 'User_Score': 'user_score', 'Rating': 'rating'})

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Не надо переименовывать столбцы через атрибут columns, потому что так ты неявно учитываешь порядок столбцов. Если порядок столбцов поменяется, код перестанет работать. Используй вместо этого метод rename().
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Так мы именно переименовываем столбцы, а не создаем новый набор названий параметров.
#
# </div>

# %%
#Преобразуем тип столбца 'year_of_release' в 'Int64', так как это год
df['year_of_release'] = df['year_of_release'].astype('Int64')

# %%
df['user_score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 1.5       2
# 0.6       2
# 1.9       2
# 9.7       1
# 0         1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# tbd - To Be Determined, то есть "Будет определено". В столбце user_score эта аббревиатура значит,
# что пользователи еще не определились с рейтингом. Значит, можно заменить эти значения на NaN, но так как NaN'ы обозначают другой вид пропусков, воспользуемся произвольной константой, например -1.

# %%
df['user_score'] = df['user_score'].replace('tbd', -1)
df['user_score'] = df['user_score'].astype('float64')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Верно, по своей сути tbd и является пропуском. Отлично, что определяешь неявные пропущенные значения.
#
# </div>

# %%
#проверим
df['user_score'].value_counts()
# Out:
# -1.0    2424
#  7.8     324
#  8.0     290
#  8.2     282
#  8.3     254
#         ...
#  1.1       2
#  2.3       2
#  1.5       2
#  0.0       1
#  9.7       1
# Name: user_score, Length: 96, dtype: int64

# %%
#Проверим типы столбцов
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null Int64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null float64
# rating             9949 non-null object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Подумай также о возможных причинах появления пропусков, а также о том, являются ли они случайными или нет. Можно высказать предварительные варианты их обработки.
#
# Первый взгляд на таблицу выполнен.
#
# </div>

# %% [markdown]
# ## Ответ
#
# Большинство пропусков в столбцах critic_score, user_score, rating. Предположительно, часть из них неслучайна. Это может быть связано с тем, что игры с пропусками вышли довольно рано и в те годы не было принято оценивать игры. Пропуски в столбце year_of_releasе могут быть как и случайны, так и связвны с тем, что игра вышла раньше на другой платформе. Пропущенных названий игры всего 2, поэтому они точно не являются системными. Это случайная утечка.

# %% [markdown]
# ### Обработка пропусков

# %%
#Найдем кол-во пропусков в каждом столбце
df.isnull().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Пропуски в столбце name не несут важной информацией, поэтому их можно заменить какой-либо строкой, например, отмечающей отсутствие имени
#
# В столбце genre аналогичная ситуация, вероятно, что пропущенные значения в этих столбцах принадлежат двум играм с отсутствующими именами.
#
# Cамое большое количество пропусков в столбце user_score. Так как количество значений tbd составляет 2424, то остальные значения потеряны. В таком случае, их можно заполнить. Можно использовать как среднее(медиану или моду), так и константу, обозначающую потерянное значение.
#
# В столбце critic_score можно поступить аналогично с user_score.
#
# В столбце rating пропуски можно заменить значением UD(undefined).
#
# В столбце year_of_release пропуски так же можно заменить константой, обозначающей пропуск или удалить, так как строки с ними составляют около 1.5% датасета

# %%
#Заполнение пропусков
df['name'] = df['name'].fillna('miss_name') 
df['genre'] = df['genre'].fillna('miss_genre')
#df['user_score'] = df['user_score'].fillna(df['user_score'].median())
#df['critic_score'] = df['critic_score'].fillna(df['critic_score'].median())
df['rating'] = df['rating'].fillna('UD') 
df['year_of_release'] = df['year_of_release'].fillna(9999)

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Заполнение такого числа пропусков в отзывах критиков и пользователей одним значением может сильно исказить структуры данных столбцов. Данных для того, чтобы восстановить эти пропуски, у нас недостаточно. Также мы видим, что пропуски в столбцах часто встречаются вместе, т.е. нет данных по одним и тем же играм. Это с большой долей вероятности связано с тем, что эти данные просто не были загружены в таблицу. Попробуй оставить пропуски и посмотреть на результаты без их заполнения.
#
# </div>

# %% [markdown]
# ## Ответ.
# Оставил без заполнения

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Верное решение. Заполнить такую часть пропусков мы не можем. Данных для этого просто недостаточно.
#
# </div>

# %%
#Проверка
df.isnull().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating                0
# dtype: int64

# %%
#Суммарные продажи во всех регионах 
df['all_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %%
df.head(1)
# Out:
#          name platform  year_of_release   genre  na_sales  eu_sales  jp_sales  \
# 0  Wii Sports      Wii             2006  Sports     41.36     28.96      3.77
#
#    other_sales  critic_score  user_score rating  all_sales
# 0         8.45          76.0         8.0      E      82.54

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Восстановить пропущенные значения мы не можем. Данных для этого недостаточно. Лучше работать с меньшим количеством данных хорошего качества.
#
# Ошибки в данных устранены. Данные подготовлены к дальнейшему анализу.
#
# </div>

# %% [markdown]
# ### Исследовательский анализ данных

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(18, 5))
sns.countplot(data = df, x='year_of_release')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Как думаешь, какова причина появления спада в индустрии последних лет?
#
# </div>

# %% [markdown]
# ## Ответ.
#
# Ячейка с описанием была выше, видимо я случайно ее отодвинул)
#
# Пик выпускаемых игр приходится на 2008-2009 годы. Далее их количество снижается. Думаю, что данные за 1980-2000 включительно не важны, потому что технологии применявшиеся при создании старых игр уже не используются. По этой же причине начиная с 2010 года количество игр снижается: игры перестали удивлять так, как раньше. Плюс игры стали выпускаться на мобильных платформах, которые отсутствуют в датасете.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Да, соглашусь с причинами спада.
#
# </div>

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(18, 5))
sns.barplot(data = df, x='platform', y='all_sales')

# %% [markdown]
# Топ наиболее прибыльных платформ: GB, NES, GEN.

# %%
platform_grouped = df.pivot_table(index='platform', values='all_sales', aggfunc='sum').sort_values(
    by='all_sales', ascending=False)
platform_grouped = platform_grouped.head(10).reset_index()
#platform_grouped
top_platforms = platform_grouped['platform'].unique() #создадим список наиболее прибыльных платформ

# %%
top_platforms
# Out:
# array(['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS', 'GBA', 'PS4', 'PSP', 'PC'],
#       dtype=object)

# %% [markdown]
# Из графиков видим, что характерный период существования платформы примерно равен 10 годам.
# Возьмем в качестве актуального период 2006-2016гг.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Значение средней продолжительности существования платформы приведено. Однако выводы ты делаешь по графикам. Стоит также привести расчет данного значения. Подумай, стоит ли включать в расчет все платформы. Будут ли выбросы по продолжительности существования платформ?
#
# </div>

# %% [markdown]
# ## Ответ
#
# Я не понимаю, как можно расчитать это значение(

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Для каждой платформы мы знаем минимальный и максимальный год выхода игр на нее. Взяв разницу этих значений, мы можем рассчитать период жизни каждой платформы. Затем стоит выделить те платформы, которые закончили свой "путь" и по ним рассчитать среднюю продолжительность жизни.
#
# </div>

# %%
actual_data = df.query('year_of_release > 2006') #возьмем все данные после 2006 года
actual_data.shape
# Out:
# (9596, 12)

# %%
actual = actual_data.pivot_table(index=['platform'], values='all_sales', aggfunc='sum').reset_index().sort_values(by='all_sales', ascending=False)

sns.set_style('darkgrid')
plt.figure(figsize=(18, 5))
sns.barplot(data = actual, x='platform', y='all_sales')

# %% [markdown]
# По продажам лидируют платформы: DS, Wii, PS3, X360.
#
# Но их продажи падают. Поэтому посмотрим на на данные на ближайшем отрезке.

# %%
actual_data = df.query('year_of_release > 2014') #возьмем все данные после 2014 года
actual_data.shape
# Out:
# (1377, 12)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Актуальный период назван. Так в рассмотрение попадут только последние поколения платформ, а также будем рассматривать только конечный на данный момент интервал развития игровой индустрии.
#
# </div>

# %%
actual = actual_data.pivot_table(index=['platform'], values='all_sales', aggfunc='sum').reset_index().sort_values(by='all_sales', ascending=False)

sns.set_style('darkgrid')
plt.figure(figsize=(18, 5))
sns.barplot(data = actual, x='platform', y='all_sales')

# %% [markdown]
# Картина поменялась. Наиболее перспективны платформы: PS4, XOne, 3DS, PS3

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Да, именно эти платформы мы и можем назвать перспективными на 2017 год.
#
# </div>

# %%
plt.figure(figsize=(18, 5))
plot = sns.boxplot(x =df['all_sales'], orient = 'v',width = 0.2)
plot.set(ylim=(0, 1.5))
# Out:
# [(0, 1.5)]

# %%
plt.figure(figsize=(18, 5))
plot = sns.boxplot(x = df['platform'], y=df['all_sales'], orient = 'v')
plot.set(ylim=(0, 6))
# Out:
# [(0, 6)]

# %% [markdown]
# На всех данных почти для всех платформ медиана составляет около 0,2 миллиона долларов.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера</h2>
#
# Подумай, из-за чего формируется разница между платформами. Старайся не только описывать результат, но и трактовать его.
#
# </div>

# %% [markdown]
# ## Ответ
#
# Вероятно, разница между платформами возникает из-за различных цен на игры для них.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Также свое влияние оказывает и число активных платформ на рынке.
# </div>

# %%
ps4 = df[(df['platform'] == 'PS4')]

# %%
ps4_critic = df[(df['platform'] == 'PS4')]
plt.figure(figsize=(16, 5))
sns.scatterplot(data=ps4, x='critic_score', y='all_sales')

# %%
ps4_critic = df[(df['platform'] == 'PS4')]
plt.figure(figsize=(16, 5))
sns.regplot(data=ps4, x='critic_score', y='all_sales')

# %%
ps4_user = df[(df['platform'] == 'PS4')]
plt.figure(figsize=(16, 5))
sns.scatterplot(data=ps4, x='user_score', y='all_sales')

# %%
ps4_user = df[(df['platform'] == 'PS4')]
plt.figure(figsize=(16, 5))
sns.regplot(data=ps4, x='user_score', y='all_sales')

# %% [markdown]
# В случае с оценками критиков все просто. Чем больше средняя оценка - тем больше продажи. Это логично, но почему в случае с оценкой игроков встречаются выбросы? Скорее всего, дело в том, что игроки сперва покупают игру, а затем ее оценивают. Таким образом хорошо разрекламированная плохая игра может хорошо продаться, но пользователи будут недовольны качеством и, следствательно, ставят соответствующие оценки.

# %%
ps4_corr = ps4[['all_sales' ,'critic_score', 'user_score']]
ps4_corr.corr()
# Out:
#               all_sales  critic_score  user_score
# all_sales      1.000000      0.406568    0.029110
# critic_score   0.406568      1.000000    0.509843
# user_score     0.029110      0.509843    1.000000

# %% [markdown]
# Корреляция между продажами и оценкой критиков составляет 0.338706, а между оценкой игроков 0.012031. Неправдоподбно мало, вероятно из-за способа замены пропусков в этапе обработки данных.
#
# ### После исправления
#
# Значение корреляции продажами и оценкой игроков незначительно возрасло до 0.029110.

# %%
for platform in top_platforms:
    platform_df = df[(df['platform'] == platform)]
    plt.figure(figsize=(16, 5))
    plt.title(platform)
    sns.scatterplot(data=platform_df, x='user_score', y='all_sales')

# %%
for platform in top_platforms:
    platform_df = df[(df['platform'] == platform)]
    platform_df_corr = platform_df[['all_sales' ,'critic_score', 'user_score']]
    print('\n',platform,'\n', platform_df_corr.corr())
# Out:
#  PS2
#                all_sales  critic_score  user_score
# all_sales      1.000000      0.395435    0.202771
# critic_score   0.395435      1.000000    0.383133
# user_score     0.202771      0.383133    1.000000
#
#  X360
#                all_sales  critic_score  user_score
# all_sales      1.000000      0.393736    0.165338
# critic_score   0.393736      1.000000    0.523505
# user_score     0.165338      0.523505    1.000000
#
#  PS3
#                all_sales  critic_score  user_score
# all_sales      1.000000      0.432432    0.196503
# critic_score   0.432432      1.000000    0.537812
# user_score     0.196503      0.537812    1.000000
#
#  Wii
#                all_sales  critic_score  user_score
# all_sales      1.000000      0.177560    0.172658
# critic_score   0.177560      1.000000    0.489245
# user_score     0.172658      0.489245    1.000000
#
#  DS
#                all_sales  critic_score  user_score
# all_sales      1.000000      0.236379    0.225656
# ...

# %% [markdown]
# К слову о замечании о неправдоподобности корреляции оценок пользователей и продажами для платформы PS4. Для других платформ результаты оказались более правдоподобны, так что, возможно, дело не в способе заполнения пропусков.

# %%
df_corr = df[['all_sales' ,'critic_score', 'user_score']]
df_corr.corr()
# Out:
#               all_sales  critic_score  user_score
# all_sales      1.000000      0.245507    0.163959
# critic_score   0.245507      1.000000    0.443590
# user_score     0.163959      0.443590    1.000000

# %% [markdown]
# Если посмотреть на корреляцию по всему датафрейму вне зависимости от платформы и сопоставить результаты, то окажется, что во многих случаях значения critic_score отклоняются от общего по датафрейму значения в большую сторону, а user_score близки к нему.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Результат получен. Подумай, чем он вызван. Здорово, что рассмотрены несколько платформ, а также то, что процесс анализа автоматизирован.
#
# </div>

# %% [markdown]
# ## Ответ
#
# Вероятно такой результат получается из-за авторитета критиков. Если знающий человек говорит, что игра хорошая и стоит потратить на нее деньги, то игроки верят ему и идут приобретать объективно оцененную игру.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Да, а еще пользователь должен купить игру перед выставлением ей оценки.
#
# </div>

# %% [markdown]
# ### Распределение игр по жанрам.

# %%
#Общее кол-во игр каждого жанра
plt.figure(figsize=(18, 5))
sns.countplot(x="genre", data=df,order = df['genre'].value_counts().index)

# %%
#Продажи по жанрам
plt.figure(figsize=(18, 5))
sns.barplot(data = df, x='genre', y='all_sales')

# %%
#Продажи по жанрам на актуальном временном промежутке
plt.figure(figsize=(18, 5))
sns.barplot(data = actual_data, x='genre', y='all_sales')

# %% [markdown]
# Топ жанров по выручке за все время:
#
# 1) Miss_genre(потерянный или смешанный)
#
# 2) Platform
#
# 3) Shooter
#
# 4) Role-playing
#
#
# Топ жанров по выручке за последнее время:
#
# 1) Shooter
#
# 2) Sports
#
# 3) Role-playing
#
# 4) Fighting
#
#
# Какие можно сделать выводы? Платформерные игры потеряли актуальность. Шутеры становятся все популярнее и показывают высокую доходность, так как начинают выходить на консолях, поэтому их тяжелее спиратить. То же самое касается спортивных симуляторов и файтингов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Анализ популярности жанров проведен. Однако не стоит забывать, что производство игр в жанрах Action или Shooter обходится сильно дороже, чем производство Puzzle-игр.
#
# </div>

# %% [markdown]
# ### Портрет пользователя каждого региона

# %% [markdown]
# Самые популярные платформы (топ-5)

# %%
actual_data.groupby(by='platform').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar')
actual_data.groupby(by='platform').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar')
actual_data.groupby(by='platform').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
# В Японии играют только на "родных" платформах.
#
# В Северной Америке доминирующий раньше "родной" X-box уступил первое место японской  PS4.
#
# В Европе же большинство выбирает японскую платформу PS4, XOne отстает. Так же это единственный регион в топе которого находится PC.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Анализировать стоит данные актуального периода. Не зря же ты его выделял. Нам важно оценить последние тенденции индустрии, и сходя из анализа которых мы и построим прогноз на 2017 год.
#
# </div>

# %% [markdown]
# ## Ответ
#
# Замечание принято и ошибка исправлена

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Это позволит нам увеличить качество анализа и качество прогноза на 2017 год.
#
# </div>

# %% [markdown]
# Самые популярные жанры (топ-5)

# %%
df.groupby(by='genre').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar')
df.groupby(by='genre').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar')
df.groupby(by='genre').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
# Игровые предпочтения жителей Северной Америки и Европы идентичны. А жители Японии обожают ролевые игры, в остальном, они похожи на жителей Северной Америки.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Из-за чего японский рынок игр так сильно отличается от других?
#
# </div>

# %% [markdown]
# ## Ответ
#
# Он отличается только доминирущим (хотя и довольно сильно) жанром. Причиной являются культурные особенности, какие именно, пришлось гуглить:
#
# Шутеры про Вторую мировую в Японии не популярны в силу очевидных исторических причин. Для вошедшей в состав нацистской коалиции Японии эта война закончилась сокрушительным поражением, атомной бомбардировкой и запретом иметь собственную армию. Неудивительно, что после этого в качестве героев своих игр японцы предпочитают видеть не спецназовцев, а самураев, волшебников и пилотов гигантских роботов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Да, культурные особенности сильно сказываются. Отличный разбор 👍
#
# </div>

# %% [markdown]
# Влияние рейтинга ESRB на продажи в отдельном регионе

# %%
df.groupby(by='rating').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar')
df.groupby(by='rating').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar')
df.groupby(by='rating').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar')

# %%
ESRB = {'E': 'Для всех', 'M': '> 17 лет', 'T': '13-19 лет', 'E10+': '>10 лет', 'K-A': 'Для всех(устар.)'}

df['ESRB_means'] = df[df['rating'].notnull()]['rating'].map(ESRB)

# %%
df.groupby(by='ESRB_means').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar')
df.groupby(by='ESRB_means').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar')
df.groupby(by='ESRB_means').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
# Максимальная часть выручки для каждой страны относится к рейтингу Е(К-А). В Японии и Северной Америке на втором месте рейтинг Т,
# а в Европе М. В общем, для всех стран отличия незначительны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Портрет типичного пользователя каждого из регионов получен. Приведены все необходимые графики. Подумай над особенностями каждого из регионов.
#
# </div>

# %% [markdown]
# ### Исследование статистических показателей

# %%
#Пользовательский рейтинг по жанрам 
plt.figure(figsize=(18, 5))
sns.barplot(data = df, x='genre', y='user_score')

# %%
df['user_score'][df['user_score'] >= 0].describe()
# Out:
# count    7590.000000
# mean        7.125046
# std         1.500006
# min         0.000000
# 25%         6.400000
# 50%         7.500000
# 75%         8.200000
# max         9.700000
# Name: user_score, dtype: float64

# %%
plt.figure(figsize=(18, 5))
sns.distplot(df['user_score'][df['user_score'] >= 0])

# %%
#Рейтинг критиков по жанрам 
plt.figure(figsize=(18, 5))
sns.barplot(data = df, x='genre', y='critic_score')

# %%
df['critic_score'].describe()
# Out:
# count    8137.000000
# mean       68.967679
# std        13.938165
# min        13.000000
# 25%        60.000000
# 50%        71.000000
# 75%        79.000000
# max        98.000000
# Name: critic_score, dtype: float64

# %%
plt.figure(figsize=(18, 5))
sns.distplot(df["critic_score"].dropna(axis = 0))

# %%
genres = df['genre'].unique()
genres
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', 'miss_genre'], dtype=object)

# %%
for platform in top_platforms:
    platform_df = df[(df['platform'] == platform)]
    plt.figure(figsize=(16, 5))
    plt.title(platform)
    sns.scatterplot(data=platform_df, x='user_score', y='all_sales')

# %%
#пользовательский рейтинг в различных жанрах
for genre in genres:
    genre_df = df[(df['genre'] == genre)]
    plt.figure(figsize=(16, 5))
    plt.title(genre)
    sns.distplot(df['user_score'][df['user_score'] >=0].dropna(axis = 0)[df['genre'] == genre])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:198: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/conda/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
for genre in genres:
    #genre_df = df[(df['genre'] == genre)]
    genre_df = df[df['user_score'] >=0].dropna(axis = 0)[df['genre'] == genre]
    print('\n',' Дисперсия user_score: ',genre_df['user_score'].var(),'\n',' Статистические показатели оценки пользователей для жанра: ', genre,'\n',genre_df['user_score'].describe())
# Out:
#   Дисперсия user_score:  2.0856072065874054
#   Статистические показатели оценки пользователей для жанра:  Sports
#  count    965.000000
# mean       7.118342
# std        1.444163
# min        0.700000
# 25%        6.300000
# 50%        7.500000
# 75%        8.200000
# max        9.500000
# Name: user_score, dtype: float64
#
#   Дисперсия user_score:  2.0797169000617277
#   Статистические показатели оценки пользователей для жанра:  Platform
#  count    407.000000
# mean       7.371744
# std        1.442122
# min        1.400000
# 25%        6.600000
# 50%        7.800000
# 75%        8.500000
# max        9.400000
# Name: user_score, dtype: float64
#
#   Дисперсия user_score:  2.12462479566377
#   Статистические показатели оценки пользователей для жанра:  Racing
#  count    591.000000
# mean       7.101523
# std        1.457609
# min        1.000000
# 25%        6.300000
# 50%        7.400000
# 75%        8.200000
# max        9.500000
# Name: user_score, dtype: float64
#
# ...

# %%
#рейтинг критиков в различных жанрах
for genre in genres:
    genre_df = df[(df['genre'] == genre)]
    plt.figure(figsize=(16, 5))
    plt.title(genre)
    sns.distplot(df['critic_score'][df['critic_score'] >=0].dropna(axis = 0)[df['genre'] == genre])

# %%
for genre in genres:
    #genre_df = df[(df['genre'] == genre)]
    genre_df = df[df['user_score'] >=0].dropna(axis = 0)[df['genre'] == genre]
    print('\n',' Дисперсия user_score: ',genre_df['user_score'].var(),'\n',' Статистические показатели оценки критиков для жанра: ', genre,'\n',genre_df['critic_score'].describe())
    print('\n',' Дисперсия user_score: ',genre_df['user_score'].var(),'\n',' Статистические показатели оценки пользователей для жанра: ', genre,'\n',genre_df['user_score'].describe())
# Out:
#   Статистические показатели оценки критиков для жанра:  Sports
#  count    1194.000000
# mean       71.968174
# std        13.878433
# min        19.000000
# 25%        64.000000
# 50%        75.000000
# 75%        82.000000
# max        98.000000
# Name: critic_score, dtype: float64
#
#   Статистические показатели оценки критиков для жанра:  Platform
#  count    497.00000
# mean      68.05835
# std       13.21376
# min       19.00000
# 25%       59.00000
# 50%       69.00000
# 75%       77.00000
# max       97.00000
# Name: critic_score, dtype: float64
#
#   Статистические показатели оценки критиков для жанра:  Racing
#  count    742.000000
# mean      67.963612
# std       14.248234
# min       13.000000
# 25%       59.000000
# 50%       69.000000
# 75%       79.000000
# max       96.000000
# Name: critic_score, dtype: float64
#
#   Статистические показатели оценки критиков для жанра:  Role-Playing
#  count    737.000000
# mean      72.652646
# std       11.999835
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# По заданию нас просят построить гистограмму отзывов по каждому рассматриваемому жанру. Пожалуйста, приведи необходимые графики.
#
# Также не хватает расчета стат. показателей оценок для каждого жанра. Именно для каждого жанра их стоит вывести, а не для всех данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера 2</h2>
#
# В расчеты попали нереальные значения -1. Именно по этой причине и не стоило заполнять пропуски. Исключи их и посмотри, как изменятся стат. показатели. Также нас просят рассчитать и дисперсию по оценкам различных жанров. В ее расчете тебе поможет метод var. По окончанию раздела обязательно подведи итог проведенным действиям и наблюдениям, сделанным в ходе данного анализа.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 3</h2>
#
# Результат исправлен. Однако очень не хватает выводов по проведенному анализу. Не забывай их делать. Подумай над тем, почему большая часть распределений скошена влево.
#
# </div>

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# h0 - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# h1 - Средние пользовательские рейтинги платформ Xbox One и PC различны
#
# alpha = 0.05

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Импорт необходимых библиотек следует производить в первой ячейке работы, как то рекомендует стандарт.
#
# </div>

# %%
xboxone = actual_data[(actual_data['platform'] == 'XOne') & (actual_data['user_score'] >= 0)]['user_score'].dropna(axis = 0)
pc = actual_data[(actual_data['platform'] == 'PC') & (actual_data['user_score'] >= 0)]['user_score'].dropna(axis = 0)
alpha = 0.05

# %%
#Cравним дисперсии
print('Дисперсия для XOne: ', (xboxone.std()**2))
print('Дисперсия для PC: ', (pc.std()**2))
# Out:
# Дисперсия для XOne:  2.1257920110192843
# Дисперсия для PC:  2.9685734900020613

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# Опять же анализировать стоит данные актуального периода.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Помарка исправлена.
#
# </div>

# %%
#Рассчитываем Т-критерий для средних значений двух независимых выборок.
results = st.ttest_ind(xboxone, pc, equal_var = False)

print('p-значение: ', results.pvalue, 'alpha: 0.05')

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.47442762270038485 alpha: 0.05
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Гипотезы сформулированы и проверены верно. Обрати внимание, что при оставлении пропусков в выборках, в результатах теста мы получим Nan. Такого быть не должно, пропуски перед передачей выборок в тест стоит убрать.
#
# </div>

# %% [markdown]
# h0 - Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.
#
# h1 - Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») одинаковые.
#
# alpha = 0.05

# %%
action = df[(df['genre'] == 'Action') & (df['user_score'] >= 0)]['user_score'].dropna(axis = 0)
sports = df[(df['genre'] == 'Sports') & (df['user_score'] >= 0)]['user_score'].dropna(axis = 0)
alpha = 0.05

# %%
#Cравним дисперсии
print('Дисперсия для Action: ', (action.std()**2))
print('Дисперсия для Sports: ', (sports.std()**2))
# Out:
# Дисперсия для Action:  2.031746898033205
# Дисперсия для Sports:  2.5965147189730033

# %%
#Рассчитываем Т-критерий для средних значений двух независимых выборок.
results = st.ttest_ind(xboxone, pc, equal_var = False)

print('p-значение: ', results.pvalue, 'alpha: 0.05')

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.47442762270038485 alpha: 0.05
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Прежде чем произвести проверку гипотезы через T-критерий Стьюдента произведи проверку дисперсии выборок, чтобы понять с каким параметром использовать метод проверки. Параметр equal_var ты уточнил, однако не совсем понятна причина, по которой следует использовать False.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Уточнение параметра equal_var позволяет нам увеличить точность проводимых тестов.
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Моей задачей было выявить определяющие успешность игры закономерности или факторы.
#
# В ходе проделанной работы были установлены следующие факторы:
#
#     1) Оценка критиков.
#
#         Она влияет на продажи сильнее, чем оценки пользователей.
#
#     2) Платформа (ее актуальность).
#
#         В планировании компании на 2017 год следует уделить особое внимание растущим платформам(PS4, XOne).
#
#         Так же надо обратить внимание на регион, в каждой стране своя доминирующая платформа.
#
#     3) Жанр
#
#         Самые перспективные: Action, Shooter, Sports. Для Японии Role-playing
#
#     4) Возрастной рейтинг.
#
#         Больше всех продаются игры с рейтингом Е (для всех)
#
#
# Тем не менее, не смотря на универсальные рекомендации, к разным регионам нужен разный подход.
#
# В каждой стране есть свои любимые жанры и платформы. Необходимо делать акцент и продвигать перспективные для каждой страны игры.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Выводы описаны грамотно. Приведены ответы на главные вопросы проекта. В выводах можно приводить полученные ранее значения. Также можно расписать все, что было сделано в ходе проведения работы. Еще лучше будет, если приведешь рекомендации для компании по дальнейшим действиям.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Если тебе нравится тема визуализации, то можешь изучить другие методы библиотеки seaborn. Она позволяет строить довольно презентабельные графики.
#
# Ты выполнил все пункты работы, молодец! Критических замечаний немного. Однако их важно исправить. Также есть достаточное число желтых комментариев, которые стоит исправить. Думаю, ты справишься с этим быстро. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Большая часть помарок исправлена, молодец. Остался лишь блок с расчетом стат. показателей. Как сделаешь его, присылай проект снова. Буду ждать :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 3</h2>
#
# Помарки исправлены, и теперь работа выполнена хорошо. Проект получился классным, молодец. Поздравляю со сданным проектом. Надеюсь, он был интересен и познавателен. Успехов в дальнейшем пути :)
#
# </div>
